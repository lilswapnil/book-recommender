# %% [markdown]
# # 4. Sentiment Analysis

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
from transformers import pipeline
classifier = pipeline("text-classification",
                      model="j-hartmann/emotion-english-distilroberta-base",
                      return_all_scores=True,
                      top_k=None,
                      )
classifier("nice, it's not working!")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: j-hartmann/emotion-english-distilroberta-base
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# [[{'label': 'anger', 'score': 0.28388312458992004},
#   {'label': 'sadness', 'score': 0.2707027494907379},
#   {'label': 'disgust', 'score': 0.23838593065738678},
#   {'label': 'surprise', 'score': 0.16507728397846222},
#   {'label': 'neutral', 'score': 0.02632381021976471},
#   {'label': 'fear', 'score': 0.008269091136753559},
#   {'label': 'joy', 'score': 0.007357954978942871}]]

# %%
from google.colab import drive
drive.mount('/content/drive')

# Define the path where you saved the file in Google Drive
drive_path = '/content/drive/MyDrive/categorized_books.csv'

# Load the CSV file into a pandas DataFrame
loaded_books_df = pd.read_csv(drive_path)

# Display the first few rows to verify
print(f"Successfully loaded 'books.csv' from Google Drive. Shape: {loaded_books_df.shape}")
display(loaded_books_df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Successfully loaded 'books.csv' from Google Drive. Shape: (75750, 9)
#                              author  \
# 0              Laurence M. Hauptman
# 1  Charlotte Fiell,Emmanuelle Dirix
# 2                     Andy Anderson
# 3              Carlotta R. Anderson
# 4                   Jeffrey Pfeffer
#
#                                                 desc  \
# 0  Reveals that several hundred thousand Indians ...
# 1  Fashion Sourcebook - 1920s is the first book i...
# 2  The seminal history and analysis of the Hungar...
# 3  "All-American Anarchist" chronicles the life a...
# 4  Why is common sense so uncommon when it comes ...
#
#                                                genre        isbn  rating  \
# 0  ['Nonfiction', 'Native Americans', 'North Amer...  002914180X    3.52
# 1  ['Nonfiction', 'Historical', 'Art', 'Couture',...  1906863482    4.51
# 2                            ['Politics', 'History']   948984147    4.15
# 3                               ['History', 'Labor']   814327079    3.83
# 4  ['Nonfiction', 'Romance', 'Management', 'Leade...   875848419    3.73
#
#    reviews                                              title  \
# 0        5  Between Two Fires: American Indians in the Civ...
# 1        6                           Fashion Sourcebook 1920s
# 2        2                                         Hungary 56
# 3        1  All-American Anarchist: Joseph A. Labadie and ...
# 4        7  The Human Equation: Building Profits by Puttin...
#
#                                                  tag    category
# 0  002914180X Reveals that several hundred thousa...  Nonfiction
# 1  1906863482 Fashion Sourcebook - 1920s is the f...  Nonfiction
# 2  948984147 The seminal history and analysis of ...  Nonfiction
# 3  814327079 "All-American Anarchist" chronicles ...  Nonfiction
# 4  875848419 Why is common sense so uncommon when...  Nonfiction

# %%
loaded_books_df['desc'][24]
# Out:
# "It is often said that Jane Austen in the countryside remained isolated from the great events of her time. But as Marilyn Butler points out in ,Jane Austen and the War of Ideas,, Austen was not isolated from reading novels, and novels carried controversy. The sentimental novel of the previous generation, the Jacobin novel of William Godwin, the philosophical comedy of Robert Bage and Maria Edgeworth--all conveyed their own kind of ideological meaning. By recognizing Austen's relationship to the literature of ideas, Butler offers acute readings of each of the novels and an intellectual context in which to see them as a whole."

# %%
sentence = loaded_books_df['desc'][24].split('.')
predictions = classifier(sentence)

# %%
sentence[3]
# Out:
# " By recognizing Austen's relationship to the literature of ideas, Butler offers acute readings of each of the novels and an intellectual context in which to see them as a whole"

# %%
predictions[3]
# Out:
# [{'label': 'neutral', 'score': 0.8888023495674133},
#  {'label': 'disgust', 'score': 0.03493865206837654},
#  {'label': 'surprise', 'score': 0.027863750234246254},
#  {'label': 'joy', 'score': 0.017199544236063957},
#  {'label': 'anger', 'score': 0.01488419622182846},
#  {'label': 'fear', 'score': 0.009897463954985142},
#  {'label': 'sadness', 'score': 0.006413999944925308}]

# %%
predictions
# Out:
# [[{'label': 'neutral', 'score': 0.687609851360321},
#   {'label': 'sadness', 'score': 0.2038654088973999},
#   {'label': 'disgust', 'score': 0.047023311257362366},
#   {'label': 'surprise', 'score': 0.025566527619957924},
#   {'label': 'fear', 'score': 0.02214357629418373},
#   {'label': 'anger', 'score': 0.008473844267427921},
#   {'label': 'joy', 'score': 0.005317436996847391}],
#  [{'label': 'anger', 'score': 0.6759650707244873},
#   {'label': 'neutral', 'score': 0.12744085490703583},
#   {'label': 'disgust', 'score': 0.06901725381612778},
#   {'label': 'fear', 'score': 0.06472213566303253},
#   {'label': 'sadness', 'score': 0.03916379436850548},
#   {'label': 'surprise', 'score': 0.013993540778756142},
#   {'label': 'joy', 'score': 0.009697407484054565}],
#  [{'label': 'neutral', 'score': 0.4394741952419281},
#   {'label': 'joy', 'score': 0.3395615518093109},
#   {'label': 'sadness', 'score': 0.09486804902553558},
#   {'label': 'disgust', 'score': 0.05349975824356079},
#   {'label': 'surprise', 'score': 0.04398325830698013},
#   {'label': 'fear', 'score': 0.014398773200809956},
#   {'label': 'anger', 'score': 0.014214531518518925}],
#  [{'label': 'neutral', 'score': 0.8888023495674133},
#   {'label': 'disgust', 'score': 0.03493865206837654},
#   {'label': 'surprise', 'score': 0.027863750234246254},
#   {'label': 'joy', 'score': 0.017199544236063957},
#   {'label': 'anger', 'score': 0.01488419622182846},
#   {'label': 'fear', 'score': 0.009897463954985142},
#   {'label': 'sadness', 'score': 0.006413999944925308}],
#  [{'label': 'neutral', 'score': 0.5494765043258667},
#   {'label': 'sadness', 'score': 0.11169024556875229},
#   {'label': 'disgust', 'score': 0.10400678217411041},
#   {'label': 'surprise', 'score': 0.07876549661159515},
#   {'label': 'anger', 'score': 0.0641336739063263},
#   {'label': 'fear', 'score': 0.051362860947847366},
#   {'label': 'joy', 'score': 0.04056445509195328}]]

# %%
sorted(predictions[3], key = lambda x: x['score'], reverse = True)
# Out:
# [{'label': 'neutral', 'score': 0.8888023495674133},
#  {'label': 'disgust', 'score': 0.03493865206837654},
#  {'label': 'surprise', 'score': 0.027863750234246254},
#  {'label': 'joy', 'score': 0.017199544236063957},
#  {'label': 'anger', 'score': 0.01488419622182846},
#  {'label': 'fear', 'score': 0.009897463954985142},
#  {'label': 'sadness', 'score': 0.006413999944925308}]

# %%
emotions = ['anger', 'disgust', 'fear', 'joy', 'neutral', 'sadness', 'surprise']

def calculate_dependent_emotions_score(predictions):
    """
    predictions: output of classifier(list_of_sentences) when top_k=None
    returns: dict[label] = max score for that label across all sentences
    """
    max_scores = {e: 0.0 for e in emotions}

    for sent_pred in predictions:           # one sentence
        for item in sent_pred:              # each emotion label for that sentence
            label = item["label"]
            score = float(item["score"])    # <- no np.float64
            if label in max_scores and score > max_scores[label]:
                max_scores[label] = score

    return max_scores

# %%
isbns = []
emotion_score = {label: [] for label in emotions}

for i in range(10):
    isbns.append(loaded_books_df["isbn"].iloc[i])
    sentences = [s.strip() for s in str(loaded_books_df["desc"].iloc[i]).split(".") if s.strip()]

    predictions = classifier(sentences, top_k=None)  # IMPORTANT
    max_scores = calculate_dependent_emotions_score(predictions)

    for label in emotions:
        emotion_score[label].append(max_scores[label])

# %%
emotion_score
# Out:
# {'anger': [0.42670348286628723,
#   0.010115593671798706,
#   0.02549857832491398,
#   0.103335902094841,
#   0.6109553575515747,
#   0.03285522758960724,
#   0.010267695412039757,
#   0.334503173828125,
#   0.03748171404004097,
#   0.05560620129108429],
#  'disgust': [0.29123973846435547,
#   0.014819956384599209,
#   0.010902597568929195,
#   0.11219137161970139,
#   0.10709736496210098,
#   0.018651600927114487,
#   0.014574062079191208,
#   0.09536799788475037,
#   0.027045676484704018,
#   0.0666540339589119],
#  'fear': [0.005444958806037903,
#   0.00960979238152504,
#   0.020019209012389183,
#   0.1266016960144043,
#   0.867803692817688,
#   0.011565250344574451,
#   0.011033313348889351,
#   0.9903721809387207,
#   0.016331251710653305,
#   0.2865256667137146],
#  'joy': [0.00474180281162262,
#   0.23418767750263214,
#   0.20866946876049042,
#   0.5710163712501526,
#   0.2706710398197174,
#   0.025995107367634773,
#   0.015627307817339897,
#   0.699333131313324,
#   0.9688493609428406,
#   0.19164903461933136],
#  'neutral': [0.1566951423883438,
#   0.9631835222244263,
#   0.48851844668388367,
#   0.7421985268592834,
#   0.7964067459106445,
#   0.9663464426994324,
#   0.8058807849884033,
#   0.842553973197937,
#   0.7199628949165344,
#   0.94572913646698],
#  'sadness': [0.10764090716838837,
#   0.026372788473963737,
#   0.0054651652462780476,
#   0.137271910905838,
#   0.04608972743153572,
#   0.021739091724157333,
#   0.014965797774493694,
#   0.03280938044190407,
#   0.078559510409832,
#   0.05802236869931221],
#  'surprise': [0.00753401592373848,
#   0.1617727428674698,
#   0.24092648923397064,
#   0.08649856597185135,
#   0.05607599392533302,
#   0.07682731002569199,
#   0.12765102088451385,
#   0.04631923884153366,
#   0.06060514226555824,
#   0.37862682342529297]}

# %% [markdown]
# ## Chunking helper (token-based, not sentence-based)

# %%
from transformers import AutoTokenizer
import numpy as np

model_name = "j-hartmann/emotion-english-distilroberta-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)

emotions = ['anger','disgust','fear','joy','neutral','sadness','surprise']

def chunk_text(text, max_tokens=512):
    # returns list of chunk strings, each <= max_tokens
    if not text:
        return [""]
    ids = tokenizer.encode(text, add_special_tokens=False)
    chunks = []
    for i in range(0, len(ids), max_tokens):
        chunk_ids = ids[i:i+max_tokens]
        chunks.append(tokenizer.decode(chunk_ids, skip_special_tokens=True))
    return chunks

# %% [markdown]
# ## Aggregate emotion scores across chunks (no truncation)

# %%
def aggregate_chunk_predictions(chunk_preds, agg="mean"):
    # chunk_preds: list of per-chunk predictions (each is list of {label, score})
    # returns dict[label] -> aggregated score
    per_label = {e: [] for e in emotions}
    for pred in chunk_preds:
        m = {d["label"]: float(d["score"]) for d in pred}
        for e in emotions:
            per_label[e].append(m.get(e, 0.0))

    if agg == "max":
        return {e: float(np.max(per_label[e])) for e in emotions}
    else:  # mean
        return {e: float(np.mean(per_label[e])) for e in emotions}

# %% [markdown]
# ## Batch over chunks (fast) and map back to books

# %%
from tqdm import tqdm
import pandas as pd

texts = loaded_books_df["desc"].fillna("").astype(str).tolist()
isbns = loaded_books_df["isbn"].tolist()

batch_size = 32

all_scores = {e: [] for e in emotions}

for text in tqdm(texts):
    chunks = chunk_text(text, max_tokens=512)

    # run classifier on all chunks in batches
    chunk_results = []
    for start in range(0, len(chunks), batch_size):
        chunk_batch = chunks[start:start+batch_size]
        chunk_results.extend(classifier(chunk_batch, top_k=None, truncation=True, max_length=512))

    scores = aggregate_chunk_predictions(chunk_results, agg="mean")  # or "max"

    for e in emotions:
        all_scores[e].append(scores[e])

# attach to df
for e in emotions:
    loaded_books_df[e] = all_scores[e]
# Out:
#   0%|          | 168/75750 [01:14<6:51:41,  3.06it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (561 > 512). Running this sequence through the model will result in indexing errors
#  99%|█████████▉| 75189/75750 [8:55:50<05:01,  1.86it/s]

# %%
emotions_df = pd.DataFrame(emotion_score)
emotions_df['isbn'] = isbns

# %%
emotions_df.head()
# Out:
#       anger   disgust      fear       joy   neutral   sadness  surprise  \
# 0  0.426703  0.291240  0.005445  0.004742  0.156695  0.107641  0.007534
# 1  0.010116  0.014820  0.009610  0.234188  0.963184  0.026373  0.161773
# 2  0.025499  0.010903  0.020019  0.208669  0.488518  0.005465  0.240926
# 3  0.103336  0.112191  0.126602  0.571016  0.742199  0.137272  0.086499
# 4  0.610955  0.107097  0.867804  0.270671  0.796407  0.046090  0.056076
#
#          isbn
# 0  002914180X
# 1  1906863482
# 2   948984147
# 3   814327079
# 4   875848419

# %%
books = pd.merge(loaded_books_df, emotions_df, on='isbn')

# %%
books
# Out:
#                              author  \
# 0              Laurence M. Hauptman
# 1  Charlotte Fiell,Emmanuelle Dirix
# 2                     Andy Anderson
# 3              Carlotta R. Anderson
# 4                   Jeffrey Pfeffer
# 5                   Jeffrey Pfeffer
# 6                   Edward Joesting
# 7             Nick Le Neve Walmsley
# 8    B. Alan Wallace,Dalai Lama XIV
# 9                       Mark Verman
#
#                                                 desc  \
# 0  Reveals that several hundred thousand Indians ...
# 1  Fashion Sourcebook - 1920s is the first book i...
# 2  The seminal history and analysis of the Hungar...
# 3  "All-American Anarchist" chronicles the life a...
# 4  Why is common sense so uncommon when it comes ...
# 5  "Competitive Advantage Through People" explore...
# 6  "Even if you know Hawaiian history you will fi...
# 7  At the time of her construction in the late 19...
# 8  Discover your personal path to bliss,"This boo...
# 9  The earliest medieval Jewish mystical writings...
#
#                                                genre        isbn  rating  \
# 0  ['Nonfiction', 'Native Americans', 'North Amer...  002914180X    3.52
# 1  ['Nonfiction', 'Historical', 'Art', 'Couture',...  1906863482    4.51
# 2                            ['Politics', 'History']   948984147    4.15
# 3                               ['History', 'Labor']   814327079    3.83
# 4  ['Nonfiction', 'Romance', 'Management', 'Leade...   875848419    3.73
# 5  ['Romance', 'Management', 'Leadership', 'Histo...  087584717X    3.65
# 6                          ['Nonfiction', 'History']   393009076    3.93
# 7                                                 []   752456830    5.00
# 8  ['Philosophy', 'Nonfiction', 'Psychology', 'Bu...  047146984X    4.10
# 9                                                 []   791407209    4.75
#
#    reviews                                              title  \
# 0        5  Between Two Fires: American Indians in the Civ...
# 1        6                           Fashion Sourcebook 1920s
# 2        2                                         Hungary 56
# 3        1  All-American Anarchist: Joseph A. Labadie and ...
# 4        7  The Human Equation: Building Profits by Puttin...
# 5        1  Competitive Advantage Through People: Unleashi...
# 6        2                        Hawaii: An Uncommon History
# 7        2                          R101: A Pictorial History
# 8        7  Genuine Happiness: Meditation as the Path to F...
# 9        1  The Books of Contemplation: Medieval Jewish My...
#
#                                                  tag    category     anger  \
# 0  002914180X Reveals that several hundred thousa...  Nonfiction  0.426703
# 1  1906863482 Fashion Sourcebook - 1920s is the f...  Nonfiction  0.010116
# 2  948984147 The seminal history and analysis of ...  Nonfiction  0.025499
# 3  814327079 "All-American Anarchist" chronicles ...  Nonfiction  0.103336
# 4  875848419 Why is common sense so uncommon when...  Nonfiction  0.610955
# 5  087584717X "Competitive Advantage Through Peop...     Fiction  0.032855
# 6  393009076 "Even if you know Hawaiian history y...  Nonfiction  0.010268
# 7  752456830 At the time of her construction in t...  Nonfiction  0.334503
# 8  047146984X Discover your personal path to blis...  Nonfiction  0.037482
# 9  791407209 The earliest medieval Jewish mystica...     Fiction  0.055606
#
#     disgust      fear       joy   neutral   sadness  surprise
# 0  0.291240  0.005445  0.004742  0.156695  0.107641  0.007534
# 1  0.014820  0.009610  0.234188  0.963184  0.026373  0.161773
# 2  0.010903  0.020019  0.208669  0.488518  0.005465  0.240926
# 3  0.112191  0.126602  0.571016  0.742199  0.137272  0.086499
# 4  0.107097  0.867804  0.270671  0.796407  0.046090  0.056076
# 5  0.018652  0.011565  0.025995  0.966346  0.021739  0.076827
# 6  0.014574  0.011033  0.015627  0.805881  0.014966  0.127651
# 7  0.095368  0.990372  0.699333  0.842554  0.032809  0.046319
# 8  0.027046  0.016331  0.968849  0.719963  0.078560  0.060605
# 9  0.066654  0.286526  0.191649  0.945729  0.058022  0.378627

# %%
drive_path_for_output = '/content/drive/MyDrive/sentiment_analyzed_books.csv'
books.to_csv(drive_path_for_output, index = False)
